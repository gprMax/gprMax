# %%
# %%writefile bowtie_antenna_model_Bscan.in
# #title: B-scan from a metal cylinder buried in a dielectric half-space with a GSSI 1.5GHz 'like' antenna
# #domain: 0.480 0.148 0.235
# #dx_dy_dz: 0.001 0.001 0.001
# #time_window: 6e-9
#
# #material: 6 0 1 0 half_space
#
# #box: 0 0 0 0.480 0.148 0.170 half_space
# #cylinder: 0.240 0 0.080 0.240 0.148 0.080 0.010 pec
#
# #python:
# from toolboxes.GPRAntennaModels.GSSI import antenna_like_GSSI_1500
# antenna_like_GSSI_1500(0.105 + current_model_run * 0.005, 0.074, 0.170, 0.001)
# #end_python:
#
# #geometry_view: 0 0 0 0.480 0.148 0.235 0.001 0.001 0.001 cylinder_GSSI_1500 n
# Out:
# Overwriting bowtie_antenna_model_Bscan.in

# %%
import gprMax
gprMax.run(inputfile = "bowtie_antenna_model_Bscan.in", n = 3)
# Out:
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v4.0.0b0 (Càrn Mòr)
#
#  Copyright (C) 2015-2023: The University of Edinburgh, United Kingdom
#  Authors: Craig Warren, Antonis Giannopoulos, and John Hartley
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# fedora | ASUSTeK COMPUTER INC. VivoBook_ASUSLaptop X512FLC_X512FL | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 7.6 GiB | Linux-6.4.11-200.fc38.x86_64-x86_64-with-glibc2.37
# |--->OpenMP: 4 threads
#
# --- Model 1/3, input file: bowtie_antenna_model_Bscan.in ----------------------
#
# #python blocks are deprecated and will be removed in the next release of gprMax. Please convert your model to use our Python API instead.
#
# Constants/variables used/available for Python scripting: {antenna_like_GSSI_1500: <function antenna_like_GSSI_1500 at 0x7fe8ba09ea20>, c: 299792458.0, current_model_run: 1, e0: 8.8541878128e-12, inputfile: /home/srutanik/GSoC/bowtie_antenna_model_Bscan/bowtie_antenna_model_Bscan.in, m0: 1.25663706212e-06, number_model_runs: 3, z0: 376.73031366686166}
#
# Model title: B-scan from a metal cylinder buried in a dielectric half-space with a GSSI 1.5GHz 'like' antenna
# Spatial discretisation: 0.001 x 0.001 x 0.001m
# Domain size: 0.48 x 0.148 x 0.235m (480 x 148 x 235 = 1.66944e+07 cells)
# Mode: 3D
# Time step (at CFL limit): 1.92583e-12 secs
# Time window: 6e-09 secs (3117 iterations)
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.48m, 0.148m, 0.235m, discretisation 0.001m, 0.001m, 0.001m, with filename base cylinder_GSSI_1500 created.
# Box from 0m, 0m, 0m, to 0.48m, 0.148m, 0.17m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.24m, 0m, 0.08m and 0.24m, 0.148m, 0.08m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
#
# Memory required (estimated): ~2.0 GB [main_grid] + ~65.0 MB overhead = 2.1 GB
#
# PML boundaries [main_grid]: {formulation: HORIPML, order: 1, thickness (cells): 10}
# Building PML boundaries [main_grid]:   0%|               | 0/6 [00:00<?, ?it/s]
# Building PML boundaries [main_grid]: 100%|█████| 6/6 [00:00<00:00, 1556.71it/s]
# Building Yee cells [main_grid]: 100%|████████████| 2/2 [00:01<00:00,  1.66it/s]
#
# Materials [main_grid]:
#     (0x(B                                             (0x(B                     (0x(B       (0x(B sigma (0x(B      (0x(B sigma*  (0x(B Dielectric
#  ID (0x(B Name                                        (0x(B Type                (0x(B eps_r (0x(B [S/m] (0x(B mu_r (0x(B [Ohm/m] (0x(B smoothable
# (0qqqqnqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqnqqqqqqqqqqqqqqqqqqqqqnqqqqqqqnqqqqqqqnqqqqqqnqqqqqqqqqnqqqqqqqqqqqq(B
#   0 (0x(B pec                                         (0x(B builtin             (0x(B 1     (0x(B inf   (0x(B 1    (0x(B 0       (0x(B False
#   1 (0x(B free_space                                  (0x(B builtin             (0x(B 1     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   2 (0x(B half_space                                  (0x(B                     (0x(B 6     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   3 (0x(B free_space+free_space+half_space+half_space (0x(B dielectric-smoothed (0x(B 3.5   (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#
# Numerical dispersion analysis [main_grid] not carried out as no waveform detected.
#
# Output directory: /home/srutanik/GSoC/bowtie_antenna_model_Bscan
#
# Writing geometry view file 1/1, cylinder_GSSI_15001.vti:   0%| | 0.00/66.8M [00
# Writing geometry view file 1/1, cylinder_GSSI_15001.vti: 100%|█| 66.8M/66.8M [0
#
# Model 1/3 on fedora with OpenMP backend using 4 thread(s)
# |--->: 100%|███████████████████████████████| 3117/3117 [12:40<00:00,  4.10it/s]
#
# Memory used (estimated): ~1.8 GB
# Time taken: 12 minutes and 33.9079 seconds
#
# --- Model 2/3, input file: bowtie_antenna_model_Bscan.in ----------------------
#
# #python blocks are deprecated and will be removed in the next release of gprMax. Please convert your model to use our Python API instead.
#
# Constants/variables used/available for Python scripting: {antenna_like_GSSI_1500: <function antenna_like_GSSI_1500 at 0x7fe8ba09ea20>, c: 299792458.0, current_model_run: 2, e0: 8.8541878128e-12, inputfile: /home/srutanik/GSoC/bowtie_antenna_model_Bscan/bowtie_antenna_model_Bscan.in, m0: 1.25663706212e-06, number_model_runs: 3, z0: 376.73031366686166}
#
# Model title: B-scan from a metal cylinder buried in a dielectric half-space with a GSSI 1.5GHz 'like' antenna
# Spatial discretisation: 0.001 x 0.001 x 0.001m
# Domain size: 0.48 x 0.148 x 0.235m (480 x 148 x 235 = 1.66944e+07 cells)
# Mode: 3D
# Time step (at CFL limit): 1.92583e-12 secs
# Time window: 6e-09 secs (3117 iterations)
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.48m, 0.148m, 0.235m, discretisation 0.001m, 0.001m, 0.001m, with filename base cylinder_GSSI_1500 created.
# Box from 0m, 0m, 0m, to 0.48m, 0.148m, 0.17m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.24m, 0m, 0.08m and 0.24m, 0.148m, 0.08m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
#
# Memory required (estimated): ~2.0 GB [main_grid] + ~65.0 MB overhead = 2.1 GB
#
# PML boundaries [main_grid]: {formulation: HORIPML, order: 1, thickness (cells): 10}
# Building PML boundaries [main_grid]:   0%|               | 0/6 [00:00<?, ?it/s]
# Building PML boundaries [main_grid]: 100%|█████| 6/6 [00:00<00:00, 1696.61it/s]
# Building Yee cells [main_grid]:   0%|                    | 0/2 [00:00<?, ?it/s]
# Building Yee cells [main_grid]: 100%|████████████| 2/2 [00:01<00:00,  1.48it/s]
#
#     (0x(B                                             (0x(B                     (0x(B       (0x(B sigma (0x(B      (0x(B sigma*  (0x(B Dielectric
#  ID (0x(B Name                                        (0x(B Type                (0x(B eps_r (0x(B [S/m] (0x(B mu_r (0x(B [Ohm/m] (0x(B smoothable
# (0qqqqnqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqnqqqqqqqqqqqqqqqqqqqqqnqqqqqqqnqqqqqqqnqqqqqqnqqqqqqqqqnqqqqqqqqqqqq(B
#   0 (0x(B pec                                         (0x(B builtin             (0x(B 1     (0x(B inf   (0x(B 1    (0x(B 0       (0x(B False
#   1 (0x(B free_space                                  (0x(B builtin             (0x(B 1     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   2 (0x(B half_space                                  (0x(B                     (0x(B 6     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   3 (0x(B free_space+free_space+half_space+half_space (0x(B dielectric-smoothed (0x(B 3.5   (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#
# Numerical dispersion analysis [main_grid] not carried out as no waveform detected.
#
# Output directory: /home/srutanik/GSoC/bowtie_antenna_model_Bscan
#
# Writing geometry view file 1/1, cylinder_GSSI_15002.vti:   0%| | 0.00/66.8M [00
# Writing geometry view file 1/1, cylinder_GSSI_15002.vti: 100%|█| 66.8M/66.8M [0
#
# Model 2/3 on fedora with OpenMP backend using 4 thread(s)
# |--->: 100%|███████████████████████████████| 3117/3117 [13:31<00:00,  3.84it/s]
#
# Memory used (estimated): ~1.5 GB
# Time taken: 13 minutes and 20.7325 seconds
#
# --- Model 3/3, input file: bowtie_antenna_model_Bscan.in ----------------------
#
# #python blocks are deprecated and will be removed in the next release of gprMax. Please convert your model to use our Python API instead.
#
# Constants/variables used/available for Python scripting: {antenna_like_GSSI_1500: <function antenna_like_GSSI_1500 at 0x7fe8ba09ea20>, c: 299792458.0, current_model_run: 3, e0: 8.8541878128e-12, inputfile: /home/srutanik/GSoC/bowtie_antenna_model_Bscan/bowtie_antenna_model_Bscan.in, m0: 1.25663706212e-06, number_model_runs: 3, z0: 376.73031366686166}
#
# Model title: B-scan from a metal cylinder buried in a dielectric half-space with a GSSI 1.5GHz 'like' antenna
# Spatial discretisation: 0.001 x 0.001 x 0.001m
# Domain size: 0.48 x 0.148 x 0.235m (480 x 148 x 235 = 1.66944e+07 cells)
# Mode: 3D
# Time step (at CFL limit): 1.92583e-12 secs
# Time window: 6e-09 secs (3117 iterations)
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.48m, 0.148m, 0.235m, discretisation 0.001m, 0.001m, 0.001m, with filename base cylinder_GSSI_1500 created.
# Box from 0m, 0m, 0m, to 0.48m, 0.148m, 0.17m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.24m, 0m, 0.08m and 0.24m, 0.148m, 0.08m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
#
# Memory required (estimated): ~2.0 GB [main_grid] + ~65.0 MB overhead = 2.1 GB
#
# PML boundaries [main_grid]: {formulation: HORIPML, order: 1, thickness (cells): 10}
# Building PML boundaries [main_grid]:   0%|               | 0/6 [00:00<?, ?it/s]
# Building PML boundaries [main_grid]: 100%|██████| 6/6 [00:00<00:00, 875.27it/s]
# Building Yee cells [main_grid]: 100%|████████████| 2/2 [00:01<00:00,  1.46it/s]
#
# Materials [main_grid]:
#     (0x(B                                             (0x(B                     (0x(B       (0x(B sigma (0x(B      (0x(B sigma*  (0x(B Dielectric
#  ID (0x(B Name                                        (0x(B Type                (0x(B eps_r (0x(B [S/m] (0x(B mu_r (0x(B [Ohm/m] (0x(B smoothable
# (0qqqqnqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqnqqqqqqqqqqqqqqqqqqqqqnqqqqqqqnqqqqqqqnqqqqqqnqqqqqqqqqnqqqqqqqqqqqq(B
#   0 (0x(B pec                                         (0x(B builtin             (0x(B 1     (0x(B inf   (0x(B 1    (0x(B 0       (0x(B False
#   1 (0x(B free_space                                  (0x(B builtin             (0x(B 1     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   2 (0x(B half_space                                  (0x(B                     (0x(B 6     (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#   3 (0x(B free_space+free_space+half_space+half_space (0x(B dielectric-smoothed (0x(B 3.5   (0x(B 0     (0x(B 1    (0x(B 0       (0x(B True
#
# Numerical dispersion analysis [main_grid] not carried out as no waveform detected.
#
# Output directory: /home/srutanik/GSoC/bowtie_antenna_model_Bscan
#
# Writing geometry view file 1/1, cylinder_GSSI_15003.vti:   0%| | 0.00/66.8M [00
# Writing geometry view file 1/1, cylinder_GSSI_15003.vti: 100%|█| 66.8M/66.8M [0
#
# Model 3/3 on fedora with OpenMP backend using 4 thread(s)
# |--->: 100%|███████████████████████████████| 3117/3117 [13:33<00:00,  3.83it/s]
#
# Memory used (estimated): ~2.6 GB
# Time taken: 13 minutes and 0.6302 seconds
#
# === Simulation completed in 39 minutes and 10.5866 seconds ====================
