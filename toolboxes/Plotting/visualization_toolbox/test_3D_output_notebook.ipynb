# %%
from plot_3D_model import visualize_vti_output

# %%
visualize_vti_output('simplebscan.vti','xy')
# Out:
# gprMax version: 4.0.0b0
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1C96E5EF760>
